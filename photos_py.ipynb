# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhaji24/ajee/blob/main/photos_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from flask import Flask, render_template, request, jsonify
from base64 import b64decode
import cv2
import numpy as np
from deepface import DeepFace
import os

app = Flask(__name__)

# Function to convert base64 string to OpenCV image
def base64_to_image(base64_string):
    """
    Params:
    base64_string: Base64 encoded image string
    Returns:
    img: OpenCV BGR image
    """
    # Decode base64 string to bytes
    image_bytes = b64decode(base64_string.split(',')[1])
    # Convert bytes to numpy array
    jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
    # Decode numpy array into OpenCV BGR image
    img = cv2.imdecode(jpg_as_np, flags=1)
    return img

# Function to check if face exists in database
def check_face_existence(target_image, database_images_paths):
    for image_path in database_images_paths:
        db_image = cv2.imread(image_path)
        result = DeepFace.verify(target_image, db_image)
        if result["verified"]:
            return True
    return False

def get_image_paths(folder_path):
    image_paths = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            image_paths.append(os.path.join(folder_path, filename))
    return image_paths

@app.route('/')
def index():
    print(os.getcwd())
    return render_template('index.html')

@app.route('/check_face', methods=['POST'])
def check_face():
    # Get base64 image from the request
    base64_image = request.form['image']

    # Convert base64 image to OpenCV format
    target_image = base64_to_image(base64_image)
    database_images_folder_paths = 'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\'
    database_images_paths = get_image_paths(database_images_folder_paths)

    # Paths to database images
    database_images_paths = [

'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2723.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2724.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2725.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2726.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2727.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2728.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2729.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2730.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2731.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2732.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2733.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2734.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2736.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2737.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2739.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2740.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2741.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2742.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2743.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2744.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2745.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2746.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2747.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2748.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2749.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2750.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2751.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2752.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2753.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2754.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2755.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2756.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2758.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2759.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2760.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2761.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2762.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2763.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2764.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2765.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2766.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2767.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2768.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2769.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2770.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2771.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2772.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2773.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2774.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2775.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2776.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2777.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2778.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2779.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2780.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2781.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2782.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2783.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2784.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2785.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2786.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2787.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2788.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2789.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2790.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2791.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2793.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2794.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2795.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2796.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2797.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2798.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2799.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2800.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2801.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2802.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2803.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2804.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2805.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2806.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2807.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2808.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2809.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2810.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2811.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2812.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2813.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2814.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2815.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2816.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2817.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2818.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2819.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2820.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2821.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2822.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2823.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2824.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2825.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2826.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2827.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2828.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2829.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2830.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2831.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2832.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2833.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2834.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2835.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2836.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2837.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2838.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2839.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2840.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2841.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2842.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2843.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2844.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2845.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2846.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2847.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2848.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2849.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2850.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2851.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2852.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2853.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2854.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2855.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2856.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2857.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2858.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2859.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2860.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2861.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2862.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2863.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2864.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2865.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2866.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2867.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2868.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_2869.JPG',
'C:\\Users\\subha\\OneDrive\\Desktop\\jessy\\SAI_